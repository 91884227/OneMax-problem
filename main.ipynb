# %% [markdown]
# # import tool

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tnrange, tqdm_notebook

# %% [markdown]
# # import self-define tool

# %%
import myGA.GA as ga

# %% [markdown]
# # Q3

# %%
q = ga.Roulette_GA()
q(10)
# Out:
# ...
# average of the best fitness values: 60.00

# %% [markdown]
# # Q4

# %%
q = ga.Q4()
q(10)
# Out:
# ...
# average of the best fitness values: 845.80

# %% [markdown]
# # Q6

# %%
q = ga.Tournament_GA()
q(10)
# Out:
# ...
# average of the best fitness values: 60.00

# %% [markdown]
# # Q7

# %%
q = ga.Q7()
q(10)
# Out:
# ...
# average of the best fitness values: 860.00
